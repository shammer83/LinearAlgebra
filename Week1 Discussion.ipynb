# %% [markdown]
#                                                                                                 Derek Haynes
#                                                                                                 Week 1 Discussion
#                                                                                                 Math 303

# %% [markdown]
# # Week 1 Discussion

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pwd
# Out:
# '/Users/derekhaynes/Documents/Math303'

# %%
plt.figure(figsize = (8, 11))

img=mpimg.imread('Week1Discussion/Screen Shot 2019-08-28 at 7.37.10 PM.png')
imgplot = plt.imshow(img, aspect = 'auto')

plt.axis('Off')
plt.show()

# %%
plt.figure(figsize = (12, 14))

img=mpimg.imread('Week1Discussion/Screen Shot 2019-09-04 at 7.48.00 PM.png')
imgplot = plt.imshow(img, aspect = 'auto')

plt.axis('Off')
plt.show()

# %%
plt.figure(figsize = (12, 14))

img=mpimg.imread('Week1Discussion/Screen Shot 2019-09-04 at 7.49.57 PM.png')
imgplot = plt.imshow(img, aspect = 'auto')

plt.axis('Off')
plt.show()
